# %% [markdown]
# <a href="https://colab.research.google.com/github/NajdekMonika/Titanic/blob/master/Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/NajdekMonika/Titanic
# Out:
# Cloning into 'Titanic'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 19 (delta 5), reused 3 (delta 0), pack-reused 0
# Receiving objects: 100% (19/19), 142.89 KiB | 6.49 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# %ls
# Out:
# sample_data/  Titanic/

# %%
# %ls Titanic/Data/
# Out:
# test_titanic.csv  train_titanic.csv

# %%
import pandas as pd
d = pd.read_csv("Titanic/Data/train_titanic.csv")

# %%
d.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
d.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
d["Age"].isnull().sum()
# Out:
# 177

# %%
age_max = d["Age"].max()
age_min = d["Age"].min()
import random
import numpy as np
Age = d["Age"].values

for i in range(len(Age)):
  if np.isnan(Age[i]):
    Age[i] = random.randint(round(age_min, 0), round(age_max, 0))

d["Age"] = Age

# %%
d["Age"].isnull().sum()
# Out:
# 0

# %%
d["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
Sex = d["Sex"].values
sex_list = []
for j in range(len(Sex)):
  if Sex[j] == "male":
    sex_list.append(0)
  elif Sex[j] == "female":
    sex_list.append(1)
d["Sex_Num"] = pd.Series(sex_list)

# %%
d.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Sex_Num
# 0      0         A/5 21171   7.2500   NaN        S        0
# 1      0          PC 17599  71.2833   C85        C        1
# 2      0  STON/O2. 3101282   7.9250   NaN        S        1
# 3      0            113803  53.1000  C123        S        1
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  Sex_Num      891 non-null    int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 90.6+ KB

# %%
d.hist(bins = 10, figsize = (10, 10))
# Out:
# array([[<Axes: title={'center': 'PassengerId'}>,
#         <Axes: title={'center': 'Survived'}>,
#         <Axes: title={'center': 'Pclass'}>],
#        [<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'SibSp'}>,
#         <Axes: title={'center': 'Parch'}>],
#        [<Axes: title={'center': 'Fare'}>,
#         <Axes: title={'center': 'Sex_Num'}>,
#         <Axes: title={'center': 'Fam'}>]], dtype=object)

# %%
import seaborn as sns
sns.heatmap(d.corr(), annot = True)
# Out:
# <ipython-input-14-b1c65fa32389>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(d.corr(), annot = True)
# <Axes: >

# %%
d["Fam"] = d["SibSp"] + d["Parch"]

# %%
sns.countplot(x = "Sex", hue = "Survived", data = d)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x = "Pclass", hue = "Survived", data = d)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x = "Embarked", hue = "Survived", data = d)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
d["Embarked"].isnull().sum()
# Out:
# 2

# %%
d["Embarked"].fillna("S", inplace = True)

# %%
d["Embarked"].isnull().sum()
# Out:
# 0

# %%
sns.catplot(x = "Sex", y = "Survived", hue = "Pclass", data = d, kind = "point", aspect = 1.5)

# %%
sns.catplot(x = "Sex", y ="Survived", hue = "Embarked", data = d, kind = "point", aspect = 1.5)

# %%
sns.catplot(x = "Fam", y ="Survived", hue = "Sex", data = d, kind = "point", aspect = 4)

# %%
d['Age_Group'] = 0
d.loc[((d['Age'] > 0) & d['Age'] <= 10),'Age_Group'] = 0
d.loc[(d['Age'] > 10) & (d['Age'] <= 20),'Age_Group'] = 1
d.loc[(d['Age'] > 20) & (d['Age'] <= 30),'Age_Group'] = 2
d.loc[(d['Age'] > 30) & (d['Age'] <= 40),'Age_Group'] = 3
d.loc[(d['Age'] > 40) & (d['Age'] <= 50),'Age_Group'] = 4
d.loc[(d['Age'] > 50) & (d['Age'] <= 60) ,'Age_Group'] = 5
d.loc[(d['Age'] > 60) & (d['Age'] <= 70),'Age_Group'] = 6
d.loc[(d['Age'] > 70) & (d['Age'] <= 80),'Age_Group'] = 7

# %%
d.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Sex_Num  Fam  AgeGrp  \
# 0      0         A/5 21171   7.2500   NaN        S        0    1       0
# 1      0          PC 17599  71.2833   C85        C        1    1       0
# 2      0  STON/O2. 3101282   7.9250   NaN        S        1    0       0
# ...

# %%
g = sns.FacetGrid(d, col = "Sex",  row = "Survived", aspect = 1.5)
g.map(sns.kdeplot, "Age")

# %%
d.groupby(['Embarked','Survived']).Age.count() * 100 / d.groupby('Embarked').Age.count()
# Out:
# Embarked  Survived
# C         0           44.642857
#           1           55.357143
# Q         0           61.038961
#           1           38.961039
# S         0           66.304348
#           1           33.695652
# Name: Age, dtype: float64

# %%
d.groupby(['Sex','Survived']).Age.count() * 100 / d.groupby('Sex').Age.count()
# Out:
# Sex     Survived
# female  0           25.796178
#         1           74.203822
# male    0           81.109185
#         1           18.890815
# Name: Age, dtype: float64

# %%
d.groupby(['Pclass','Survived']).Age.count() * 100 / d.groupby('Pclass').Age.count()
# Out:
# Pclass  Survived
# 1       0           37.037037
#         1           62.962963
# 2       0           52.717391
#         1           47.282609
# 3       0           75.763747
#         1           24.236253
# Name: Age, dtype: float64
